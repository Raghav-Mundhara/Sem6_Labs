# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('heart.csv')

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.shape
# Out:
# (918, 12)

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
data.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'RestingBP'}>,
#         <Axes: title={'center': 'Cholesterol'}>],
#        [<Axes: title={'center': 'FastingBS'}>,
#         <Axes: title={'center': 'MaxHR'}>,
#         <Axes: title={'center': 'Oldpeak'}>],
#        [<Axes: title={'center': 'HeartDisease'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
data['HeartDisease'].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_28232\1119197534.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True)
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data['Sex'].replace({'M':0, 'F':1}, inplace=True)

# %%
data['Sex'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
data['ChestPainType'].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
data['ChestPainType'].replace({'ATA':0, 'NAP':1, 'ASY':2, 'TA':3}, inplace=True)

# %%
data['ChestPainType'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
data['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
data['RestingECG'].replace({'Normal':0, 'ST':1, 'LVH':2}, inplace=True)

# %%
data['RestingECG'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
data['ExerciseAngina'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
data['ExerciseAngina'].replace({'N':0, 'Y':1}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 86.2+ KB

# %%
data['ST_Slope'].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
data['ST_Slope'].replace({'Up':0, 'Flat':1, 'Down':2}, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(11)
# memory usage: 86.2 KB

# %%
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
new_data=data.drop(['RestingECG','MaxHR','Sex'], axis=1)

# %%
new_data.head()
# Out:
#    Age  ChestPainType  RestingBP  Cholesterol  FastingBS  ExerciseAngina  \
# 0   40              0        140          289          0               0
# 1   49              1        160          180          0               0
# 2   37              0        130          283          0               0
# 3   48              2        138          214          0               1
# 4   54              1        150          195          0               0
#
#    Oldpeak  ST_Slope  HeartDisease
# 0      0.0         0             0
# 1      1.0         1             1
# 2      0.0         0             0
# 3      1.5         1             1
# 4      0.0         0             0

# %%
X=new_data.drop('HeartDisease', axis=1)
y=new_data['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
loggisticModel=LogisticRegression()
loggisticModel.fit(X_train, y_train)
loggisticModel.score(X_test, y_test)
# Out:
# d:\Python\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8532608695652174

# %%
from sklearn.ensemble import RandomForestClassifier
RFCmodel=RandomForestClassifier()
RFCmodel.fit(X_train, y_train)
RFCmodel.score(X_test, y_test)
# Out:
# 0.8804347826086957

# %%
from sklearn.tree import DecisionTreeClassifier
DTmodel=DecisionTreeClassifier()
DTmodel.fit(X_train, y_train)
DTmodel.score(X_test, y_test)
# Out:
# 0.8260869565217391

# %%
from sklearn.svm import SVC
SVMmodel=SVC()
SVMmodel.fit(X_train, y_train)
SVMmodel.score(X_test, y_test)
# Out:
# 0.6304347826086957

# %%
from sklearn.naive_bayes import GaussianNB
NBmodel=GaussianNB()
NBmodel.fit(X_train, y_train)
NBmodel.score(X_test, y_test)
# Out:
# 0.8641304347826086

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNmodel=KNeighborsClassifier()
KNNmodel.fit(X_train, y_train)
KNNmodel.score(X_test, y_test)
# Out:
# 0.6793478260869565

# %%
all_models=[RFCmodel, loggisticModel, DTmodel, SVMmodel, NBmodel, KNNmodel]
accuracy=[]
for model in all_models:
    accuracy.append(model.score(X_test, y_test))

for i in range(len(all_models)):
    print("%s accuracy is %s"%(all_models[i], accuracy[i]))
# Out:
# RandomForestClassifier() accuracy is 0.8804347826086957
# LogisticRegression() accuracy is 0.8532608695652174
# DecisionTreeClassifier() accuracy is 0.8260869565217391
# SVC() accuracy is 0.6304347826086957
# GaussianNB() accuracy is 0.8641304347826086
# KNeighborsClassifier() accuracy is 0.6793478260869565

# %%
sns.heatmap(new_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
X=new_data.drop('HeartDisease', axis=1)
y=new_data['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
RFCmodel=RandomForestClassifier()
RFCmodel.fit(X_train, y_train)
RFCmodel.score(X_test, y_test)
# Out:
# 0.8695652173913043

# %%
from sklearn.linear_model import LogisticRegression
loggisticModel=LogisticRegression()
loggisticModel.fit(X_train, y_train)
loggisticModel.score(X_test, y_test)
# Out:
# d:\Python\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.8532608695652174

# %%
from sklearn.tree import DecisionTreeClassifier
DTmodel=DecisionTreeClassifier()
DTmodel.fit(X_train, y_train)
DTmodel.score(X_test, y_test)
# Out:
# 0.8260869565217391

# %%
from sklearn.svm import SVC
SVMmodel=SVC()
SVMmodel.fit(X_train, y_train)
SVMmodel.score(X_test, y_test)
# Out:
# 0.6304347826086957

# %%
from sklearn.naive_bayes import GaussianNB
NBmodel=GaussianNB()
NBmodel.fit(X_train, y_train)
NBmodel.score(X_test, y_test)
# Out:
# 0.8641304347826086

# %%
from sklearn.neighbors import KNeighborsClassifier
KNNmodel=KNeighborsClassifier()
KNNmodel.fit(X_train, y_train)
KNNmodel.score(X_test, y_test)
# Out:
# 0.6793478260869565

# %%
from sklearn.metrics import confusion_matrix
y_pred=RFCmodel.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[62, 12],
#        [12, 98]], dtype=int64)

# %%
y_pred=loggisticModel.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[61, 13],
#        [14, 96]], dtype=int64)

# %%
y_pred=DTmodel.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[61, 13],
#        [19, 91]], dtype=int64)

# %%
all_models=[RFCmodel, loggisticModel, DTmodel, SVMmodel, NBmodel, KNNmodel]
accuracy=[]
for model in all_models:
    accuracy.append(model.score(X_test, y_test))

for i in range(len(all_models)):
    print("%s accuracy is %s"%(all_models[i], accuracy[i]*100))
# Out:
# RandomForestClassifier() accuracy is 86.95652173913044
# LogisticRegression() accuracy is 85.32608695652173
# DecisionTreeClassifier() accuracy is 82.6086956521739
# SVC() accuracy is 63.04347826086957
# GaussianNB() accuracy is 86.41304347826086
# KNeighborsClassifier() accuracy is 67.93478260869566

# %%
sns.histplot(X_train)
# Out:
# <Axes: ylabel='Count'>

# %%
X_train.drop('Cholesterol', axis=1).head()
# Out:
#      Age  ChestPainType  RestingBP  FastingBS  ExerciseAngina  Oldpeak  \
# 852   43              2        120          0               1      2.5
# 121   52              1        125          0               0      0.0
# 664   65              2        150          0               0      1.0
# 187   41              2        120          1               1      1.0
# 108   50              2        140          0               0      0.0
#
#      ST_Slope
# 852         1
# 121         0
# 664         1
# 187         1
# 108         0

# %%
X_train
# Out:
#      Age  ChestPainType  RestingBP  Cholesterol  FastingBS  ExerciseAngina  \
# 852   43              2        120          177          0               1
# 121   52              1        125          272          0               0
# 664   65              2        150          225          0               0
# 187   41              2        120          237          1               1
# 108   50              2        140          129          0               0
# ..   ...            ...        ...          ...        ...             ...
# 767   54              1        108          267          0               0
# 72    52              2        120          182          0               0
# 908   63              2        140          187          0               1
# 235   39              0        120          200          0               1
# 37    41              0        110          250          0               0
#
#      Oldpeak  ST_Slope
# 852      2.5         1
# ...

# %%
new_data.head()
# Out:
#    Age  ChestPainType  RestingBP  Cholesterol  FastingBS  ExerciseAngina  \
# 0   40              0        140          289          0               0
# 1   49              1        160          180          0               0
# 2   37              0        130          283          0               0
# 3   48              2        138          214          0               1
# 4   54              1        150          195          0               0
#
#    Oldpeak  ST_Slope  HeartDisease
# 0      0.0         0             0
# 1      1.0         1             1
# 2      0.0         0             0
# 3      1.5         1             1
# 4      0.0         0             0

# %%
sns.heatmap(new_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
new_data.drop(['RestingBP'], axis=1, inplace=True)

# %%
new_data
# Out:
#      Age  ChestPainType  Cholesterol  FastingBS  ExerciseAngina  Oldpeak  \
# 0     40              0          289          0               0      0.0
# 1     49              1          180          0               0      1.0
# 2     37              0          283          0               0      0.0
# 3     48              2          214          0               1      1.5
# 4     54              1          195          0               0      0.0
# ..   ...            ...          ...        ...             ...      ...
# 913   45              3          264          0               0      1.2
# 914   68              2          193          1               0      3.4
# 915   57              2          131          0               1      1.2
# 916   57              0          236          0               0      0.0
# 917   38              1          175          0               0      0.0
#
#      ST_Slope  HeartDisease
# 0           0             0
# 1           1             1
# ...

# %%
sns.heatmap(new_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
algos=[RandomForestClassifier(), LogisticRegression(), DecisionTreeClassifier(), SVC(), GaussianNB(), KNeighborsClassifier()]
accuracy=[]
for algo in algos:
    algo.fit(X_train, y_train)
    accuracy.append(algo.score(X_test, y_test))

for i in range(len(algos)):
    print("%s accuracy is %s"%(algos[i], accuracy[i]*100))
# Out:
# RandomForestClassifier() accuracy is 88.58695652173914
# LogisticRegression() accuracy is 85.32608695652173
# DecisionTreeClassifier() accuracy is 80.97826086956522
# SVC() accuracy is 63.04347826086957
# GaussianNB() accuracy is 86.41304347826086
# KNeighborsClassifier() accuracy is 67.93478260869566
# d:\Python\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
