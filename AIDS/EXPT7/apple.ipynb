# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('apple.csv')
data
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3995  3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality
# 0    -0.491590    good
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   int64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 281.4+ KB

# %%
data.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness      Acidity
# count  4000.000000  4000.000000  4000.000000
# mean      0.512118     0.498277     0.076877
# std       1.930286     1.874427     2.110270
# min      -5.961897    -5.864599    -7.010538
# 25%      -0.801286    -0.771677    -1.377424
# 50%       0.534219     0.503445     0.022609
# ...

# %%
data.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
plt.hist(data['Size'],bins=30)
# Out:
# (array([  4.,   2.,   5.,  11.,  23.,  34.,  53.,  83., 138., 194., 239.,
#         282., 333., 355., 360., 346., 330., 302., 262., 210., 157., 104.,
#          70.,  44.,  33.,  14.,   4.,   5.,   2.,   1.]),
#  array([-7.15170306, -6.69976739, -6.24783173, -5.79589606, -5.3439604 ,
#         -4.89202473, -4.44008907, -3.9881534 , -3.53621774, -3.08428207,
#         -2.63234641, -2.18041074, -1.72847508, -1.27653941, -0.82460375,
#         -0.37266808,  0.07926759,  0.53120325,  0.98313892,  1.43507458,
#          1.88701025,  2.33894591,  2.79088158,  3.24281724,  3.69475291,
#          4.14668857,  4.59862424,  5.0505599 ,  5.50249557,  5.95443123,
#          6.4063669 ]),
#  <BarContainer object of 30 artists>)

# %%
for i in data.columns:
    plt.hist(data[i],bins=30)
    plt.title(i)
    plt.show()

# %%
data['Quality'].replace({'good':1,'bad':0},inplace=True)
data
# Out:
#       A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...    ...       ...       ...        ...          ...        ...       ...
# 3995  3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.491590        1
# ...

# %%
data.drop('A_id',axis=1,inplace=True)

# %%
# sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.drop(['Weight','Crunchiness','Acidity'],axis=1,inplace=True)

# %%
data
# Out:
#           Size  Sweetness  Juiciness  Ripeness  Quality
# 0    -3.970049   5.346330   1.844900  0.329840        1
# 1    -1.195217   3.664059   0.853286  0.867530        1
# 2    -0.292024  -1.738429   2.838636 -0.038033        0
# 3    -0.657196   1.324874   3.637970 -3.413761        1
# 4     1.364217  -0.384658   3.030874 -1.303849        1
# ...        ...        ...        ...       ...      ...
# 3995  0.059386  -3.714549   1.697986  2.244055        0
# 3996 -0.293118  -0.204020   0.024523 -1.087900        1
# 3997 -2.634515  -2.440461   2.199709  4.763859        0
# 3998 -4.008004   2.366397   2.161435  0.214488        1
# 3999  0.278540   0.121217   1.266677 -0.776571        1
#
# [4000 rows x 5 columns]

# %%
#K-Means
from sklearn.cluster import KMeans
kmeans=KMeans(n_clusters=3,random_state=1)

y_predicted=kmeans.fit_predict(data[['Sweetness','Size']])
# Out:
# d:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['cluster']=y_predicted

# %%
df1=data[data.cluster==0]
df2=data[data.cluster==1]
df3=data[data.cluster==2]

plt.scatter(df1.Sweetness,df1.Quality,color='green')
plt.scatter(df2.Sweetness,df2.Quality,color='red')
plt.scatter(df3.Sweetness,df3.Quality,color='black')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color='purple',marker='*',label='centroid')

plt.xlabel('Sweetness')
plt.ylabel('Size')
plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

scaler.fit(data[['Sweetness']])

data['Sweetness']=scaler.transform(data[['Sweetness']])

scaler.fit(data[['Size']])
data['Size']=scaler.transform(data[['Size']])
data
# Out:
#           Size  Sweetness  Juiciness  Ripeness  Quality  cluster
# 0     0.234669   0.922484   1.844900  0.329840        1        2
# 1     0.439331   0.795706   0.853286  0.867530        1        1
# 2     0.505948   0.388567   2.838636 -0.038033        0        1
# 3     0.479014   0.619422   3.637970 -3.413761        1        1
# 4     0.628107   0.490589   3.030874 -1.303849        1        0
# ...        ...        ...        ...       ...      ...      ...
# 3995  0.531867   0.239644   1.697986  2.244055        0        1
# 3996  0.505867   0.504203   0.024523 -1.087900        1        1
# 3997  0.333173   0.335661   2.199709  4.763859        0        2
# 3998  0.231869   0.697913   2.161435  0.214488        1        2
# 3999  0.548031   0.528713   1.266677 -0.776571        1        1
#
# [4000 rows x 6 columns]

# %%
kmeans=KMeans(n_clusters=3,random_state=1)

y_predicted=kmeans.fit_predict(data[['Sweetness','Size']])
data['cluster']=y_predicted

data
# Out:
# d:\Python\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#           Size  Sweetness  Juiciness  Ripeness  Quality  cluster
# 0     0.234669   0.922484   1.844900  0.329840        1        1
# 1     0.439331   0.795706   0.853286  0.867530        1        1
# 2     0.505948   0.388567   2.838636 -0.038033        0        0
# 3     0.479014   0.619422   3.637970 -3.413761        1        1
# 4     0.628107   0.490589   3.030874 -1.303849        1        2
# ...        ...        ...        ...       ...      ...      ...
# 3995  0.531867   0.239644   1.697986  2.244055        0        0
# 3996  0.505867   0.504203   0.024523 -1.087900        1        0
# 3997  0.333173   0.335661   2.199709  4.763859        0        0
# 3998  0.231869   0.697913   2.161435  0.214488        1        1
# ...

# %%
df1=data[data.cluster==0]
df2=data[data.cluster==1]
df3=data[data.cluster==2]

plt.scatter(df1.Sweetness,df1.Quality,color='green')
plt.scatter(df2.Sweetness,df2.Quality,color='red')
plt.scatter(df3.Sweetness,df3.Quality,color='black')

plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],color='purple',marker='*',label='centroid')

plt.xlabel('Sweetness')
plt.ylabel('Size')
plt.legend()
